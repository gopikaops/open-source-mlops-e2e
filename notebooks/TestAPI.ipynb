# %%
import json
import os
import time
from pathlib import Path

import numpy as np
import pandas as pd
import requests
import yaml
from box import ConfigBox
from sklearn.metrics import f1_score
from tqdm import tqdm

# %%
# local testing
API_URL = "http://0.0.0.0:8080" 
# testing deployed service
# API_URL = "https://<YOUR_APP_NAME>.fly.dev" 

API_URL
# Out:
# 'http://0.0.0.0:8080'

# %%
def load_params(params_path):
    with open(params_path, "r") as f:
        params = yaml.safe_load(f)
        params = ConfigBox(params)
    return params


proj_path = Path(os.getcwd()).parent.absolute()
params = load_params(proj_path/'params.yaml')
feat_cols = params.base.feat_cols
targ_col = params.base.targ_col
feat_cols, targ_col
# Out:
# (BoxList(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']),
#  'Exited')

# %%
df = pd.concat([pd.read_csv(proj_path/'data'/'raw'/f'Churn_Modelling_{country}.csv') for country in ['France', 'Spain']])
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15619304      Onio          502    France  Female   42       8
# 2    15701354      Boni          699    France  Female   39       1
# 3    15592531  Bartlett          822    France    Male   50       7
# 4    15792365        He          501    France    Male   44       4
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1  159660.80              3          1               0        113931.57
# 2       0.00              2          0               0         93826.63
# 3       0.00              2          1               1         10062.80
# 4  142051.07              2          0               1         74940.50
#
#    Exited
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0

# %%
my_obj = [{
    'CreditScore': 755,
    'Age': 40,
    'Tenure': 2,
    'Balance': 137430.82,
    'NumOfProducts': 2,
    'HasCrCard': 0,
    'IsActiveMember': 0,
    'EstimatedSalary': 176768.59,
    'Exited': 0
  }]

x = requests.post(API_URL + '/predict', json = my_obj)
if x.ok:
    probs = x.json()
else:
    x.raise_for_status()

probs
# Out:
# [0.905]

# %%
def get_prob(obj):
    x = requests.post(API_URL + '/predict', json = obj)
    if x.ok:
        probs = x.json()
    else:
        x.raise_for_status()
    return probs

get_prob(my_obj)
# Out:
# [0.905]

# %%
import time


def send_sample_requests(df):
    f1_score_list = []
    for _ in tqdm(range(50)):
        df_sample = df.sample(n=60)
        y_true = df_sample[targ_col].values
        obj = df_sample[feat_cols].to_dict('records')
        probs = get_prob(obj)
        y_pred = np.array([prob < 0.5 for prob in probs]).astype(int)
        f1 = f1_score(y_true, y_pred)
        f1_score_list.append(f1)
        time.sleep(1)
    return f1_score_list
        
f1_score_list = send_sample_requests(df)
f1_score_list
# Out:
# 100%|██████████| 50/50 [00:52<00:00,  1.05s/it]
# [1.0,
#  1.0,
#  0.9565217391304348,
#  0.8571428571428571,
#  0.9090909090909091,
#  1.0,
#  0.9523809523809523,
#  0.9333333333333333,
#  0.9333333333333333,
#  0.9473684210526316,
#  0.9411764705882353,
#  0.8333333333333333,
#  0.9090909090909091,
#  0.923076923076923,
#  0.5714285714285715,
#  0.9473684210526316,
#  0.6666666666666666,
#  0.8421052631578948,
#  0.923076923076923,
#  0.9411764705882353,
#  0.9473684210526316,
#  0.9411764705882353,
#  0.9333333333333333,
#  0.9523809523809523,
#  0.9523809523809523,
#  0.8571428571428571,
#  0.75,
#  0.888888888888889,
#  1.0,
#  0.888888888888889,
#  1.0,
#  0.9473684210526316,
#  0.9655172413793104,
#  1.0,
#  0.8571428571428571,
#  0.8421052631578948,
#  1.0,
#  0.9473684210526316,
#  0.8799999999999999,
#  1.0,
#  0.8421052631578948,
#  1.0,
#  1.0,
#  0.888888888888889,
#  0.8571428571428571,
#  0.9,
#  0.9333333333333333,
#  0.9473684210526316,
#  0.8,
#  1.0]

# %%
df_germany =  pd.read_csv(proj_path/'data'/'more_data'/'Churn_Modelling_Germany.csv')
# time.sleep(20) # this is to create a pause between requests. Later it'll be easier to distinguish the two types if requests
f1_score_list = send_sample_requests(df_germany)
f1_score_list
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.16/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.16/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.16/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Exited'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 df_germany =  pd.read_csv(proj_path/'data'/'more_data'/'Churn_Modelling_Germany.csv')
#       2 # time.sleep(20) # this is to create a pause between requests. Later it'll be easier to distinguish the two types if requests
# ----> 3 f1_score_list = send_sample_requests(df_germany)
#       4 f1_score_list
#
# Cell In[8], line 8, in send_sample_requests(df)
#       6 for _ in tqdm(range(50)):
#       7     df_sample = df.sample(n=60)
# ----> 8     y_true = df_sample[targ_col].values
#       9     obj = df_sample[feat_cols].to_dict('records')
#      10     probs = get_prob(obj)
#
# File ~/.pyenv/versions/3.8.16/lib/python3.8/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.pyenv/versions/3.8.16/lib/python3.8/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Exited'

# %%
x = requests.get(API_URL + '/drift_data')
if x.ok:
    data = x.json()
else:
    x.raise_for_status()

df_p_vals = pd.DataFrame(json.loads(data))
df_p_vals
# Out:
#                           time  CreditScore       Age    Tenure   Balance  \
# 0   2023-01-31 21:50:55.110631     0.055723  0.978798  0.832680  0.921336
# 1   2023-01-31 21:50:56.069961     0.206015  0.998430  0.196414  0.485389
# 2   2023-01-31 21:50:57.127098     0.569845  0.903876  0.953986  0.623703
# 3   2023-01-31 21:50:58.182128     0.521296  0.417589  0.584976  0.988387
# 4   2023-01-31 21:50:59.240637     0.733509  0.999365  0.068259  0.308989
# ..                         ...          ...       ...       ...       ...
# 95  2023-01-31 22:22:19.608795     0.197072  0.357684  0.790378  0.739466
# 96  2023-01-31 22:22:20.658040     0.422286  0.612022  0.373441  0.564114
# 97  2023-01-31 22:22:21.710600     0.195626  0.823026  0.730777  0.587478
# 98  2023-01-31 22:22:22.767501     0.093379  0.698197  0.913888  0.239719
# 99  2023-01-31 22:22:23.825099     0.456063  0.424458  0.515579  0.818738
#
#     NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0        0.145549   1.000000        1.000000         0.874650
# 1        1.000000   0.998416        0.608368         0.262404
# 2        1.000000   1.000000        0.999087         0.890148
# 3        0.995000   1.000000        1.000000         0.134168
# 4        0.995000   0.953637        0.712223         0.607063
# ..            ...        ...             ...              ...
# 95       0.784800   0.586960        0.990236         0.750290
# 96       0.945641   0.387848        0.497856         0.611413
# 97       0.750037   0.953637        0.999087         0.001212
# 98       1.000000   0.733423        0.999978         0.603501
# 99       0.750037   1.000000        1.000000         0.092182
#
# [100 rows x 9 columns]

# %%
import plotly_express as px

fig = px.line(df_p_vals, x='time', y=feat_cols)
fig.add_hline(y=0.05, line_color='red')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import plotly_express as px
#       3 fig = px.line(df_p_vals, x='time', y=feat_cols)
#       4 fig.add_hline(y=0.05, line_color='red')
#
# ModuleNotFoundError: No module named 'plotly_express'
